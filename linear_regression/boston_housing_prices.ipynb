# %% [markdown]
# # Boston Housing Linear Regression Model

# %%
import pandas as pd

# %%
! wget wget https://github.com/dataprofessor/data/raw/master/BostonHousing.csv
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
boston_housing = pd.read_csv("../data/BostonHousing.csv")
boston_housing
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
Y = boston_housing.medv
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
X=boston_housing.drop(['medv'], axis=1)
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# **Data Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((404, 13), (404,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((102, 13), (102,))

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# **Scatter Plot**

# %%
import seaborn as sns

# %%
Y_test
# Out:
# 39     30.8
# 183    32.5
# 283    50.0
# 447    12.6
# 430    14.5
#        ...
# 78     21.2
# 416     7.5
# 56     24.7
# 223    30.1
# 36     20.0
# Name: medv, Length: 102, dtype: float64

# %%
Y_pred
# Out:
# array([31.50570255, 30.11443295, 46.11387626, 17.24896346, 18.30897144,
#        22.68338732, 19.58155405, 11.74457957, 24.70371168, 23.65085285,
#        21.36421266, 14.48060219, 20.48909386, 20.59325459, 40.40036857,
#        15.32034009, 17.08240283, 15.54466714, 19.48944263, 25.68565951,
#        18.69688461, 17.73049805, 18.06806776, 34.18589393, 13.74815633,
#         9.06958949, 12.25534391, 24.96687857, 20.43843286, 22.16443241,
#        18.27115737, 32.74683971, 21.62626629, 21.23360295,  5.69888679,
#        18.93799369,  9.61184116, 24.81092736, 20.28459446, 21.27222675,
#        35.90059663, 20.28221817, 32.87191218, 33.05479614, 20.58375604,
#        23.53311996, 30.55242957, 14.55968527, 23.0911797 , 14.18314181,
#        19.92219285, 27.62672622, 16.44443784, 23.10163752, 25.95319526,
#        24.92861562, 20.38953345, 30.33824352, 16.10079568, 22.54613104,
#        20.28793919, 38.59209182, 15.72426043, 15.46164534, 36.0511403 ,
#        30.36928266, 34.52403427, 23.32219609, 25.0660745 , 28.3923236 ,
#        29.17814453, 35.49660695, 16.62034254, 20.83417738, 18.75016489,
#        18.01258854, 21.00343823, 23.79591652, 18.38901466, 25.5812494 ,
#        17.35389892, 38.72908379, 13.4765284 , 25.06768562,  8.35802571,
#        24.2675719 , 16.58767976, 33.67007497, 30.45303749, 11.6755674 ,
#        28.12023978, 17.78764956, 15.37082422, 23.05669249, 18.15044173,
#        33.64899912, 28.90948054, 21.48514132, 14.20488349, 24.94755642,
#        29.01774146, 22.03722789])

# %%
sns.scatterplot(x=Y_test, y=Y_pred)
# Out:
# <Axes: xlabel='medv'>

# %%
sns.scatterplot(x=Y_test, y=Y_pred, marker="+")
# Out:
# <Axes: xlabel='medv'>

# %%
sns.scatterplot(x=Y_test, y=Y_pred, alpha=0.5)
# Out:
# <Axes: xlabel='medv'>
